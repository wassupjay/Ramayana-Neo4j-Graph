# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: langchain-neo4j>=0.2.0 in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: langchain-groq>=0.3.6 in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (0.3.6)
# Collecting langchain-community>=0.3.27 (from -r requirements.txt (line 3))
#   Using cached langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Collecting langchain-experimental>=0.3.4 (from -r requirements.txt (line 4))
#   Downloading langchain_experimental-0.3.4-py3-none-any.whl.metadata (1.7 kB)
# Collecting wikipedia>=1.4.0 (from -r requirements.txt (line 5))
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tiktoken>=0.9.0 in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (0.9.0)
# Requirement already satisfied: neo4j>=5.27.0 in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (5.28.1)
# Requirement already satisfied: python-dotenv>=1.0.1 in /opt/homebrew/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: ipykernel>=6.29.5 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from -r requirements.txt (line 9)) (6.29.5)
# Requirement already satisfied: langchain<0.4.0,>=0.3.7 in /opt/homebrew/lib/python3.11/site-packages (from langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (0.3.26)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.8 in /opt/homebrew/lib/python3.11/site-packages (from langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (0.3.70)
# Requirement already satisfied: neo4j-graphrag<2.0.0,>=1.5.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: pytz in /opt/homebrew/lib/python3.11/site-packages (from neo4j>=5.27.0->-r requirements.txt (line 7)) (2025.2)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /opt/homebrew/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in /opt/homebrew/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (0.4.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/homebrew/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/homebrew/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /opt/homebrew/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /opt/homebrew/lib/python3.11/site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.8->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.8->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.8->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.8->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.8->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: fsspec<2025.0.0,>=2024.9.0 in /opt/homebrew/lib/python3.11/site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (2024.12.0)
# Requirement already satisfied: json-repair<0.40.0,>=0.39.1 in /opt/homebrew/lib/python3.11/site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (0.39.1)
# Requirement already satisfied: numpy<3.0.0,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (2.2.6)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /opt/homebrew/lib/python3.11/site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (5.8.0)
# Requirement already satisfied: scipy<2.0.0,>=1.13.0 in /opt/homebrew/lib/python3.11/site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: types-pyyaml<7.0.0.0,>=6.0.12.20240917 in /opt/homebrew/lib/python3.11/site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (6.0.12.20250516)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (2025.6.15)
# Requirement already satisfied: groq<1,>=0.29.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-groq>=0.3.6->-r requirements.txt (line 2)) (0.30.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/homebrew/lib/python3.11/site-packages (from groq<1,>=0.29.0->langchain-groq>=0.3.6->-r requirements.txt (line 2)) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/lib/python3.11/site-packages (from groq<1,>=0.29.0->langchain-groq>=0.3.6->-r requirements.txt (line 2)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/homebrew/lib/python3.11/site-packages (from groq<1,>=0.29.0->langchain-groq>=0.3.6->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.11/site-packages (from groq<1,>=0.29.0->langchain-groq>=0.3.6->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain-groq>=0.3.6->-r requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain-groq>=0.3.6->-r requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/homebrew/lib/python3.11/site-packages (from langchain-community>=0.3.27->-r requirements.txt (line 3)) (3.12.13)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community>=0.3.27->-r requirements.txt (line 3))
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community>=0.3.27->-r requirements.txt (line 3))
#   Using cached pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community>=0.3.27->-r requirements.txt (line 3))
#   Using cached httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->-r requirements.txt (line 3)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->-r requirements.txt (line 3)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->-r requirements.txt (line 3)) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->-r requirements.txt (line 3)) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->-r requirements.txt (line 3)) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community>=0.3.27->-r requirements.txt (line 3)) (1.20.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.27->-r requirements.txt (line 3))
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.27->-r requirements.txt (line 3))
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community>=0.3.27->-r requirements.txt (line 3))
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting beautifulsoup4 (from wikipedia>=1.4.0->-r requirements.txt (line 5))
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: regex>=2022.1.18 in /opt/homebrew/lib/python3.11/site-packages (from tiktoken>=0.9.0->-r requirements.txt (line 6)) (2024.11.6)
# Requirement already satisfied: appnope in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.29.5->-r requirements.txt (line 9)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.29.5->-r requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.29.5->-r requirements.txt (line 9)) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.29.5->-r requirements.txt (line 9)) (9.4.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.29.5->-r requirements.txt (line 9)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.29.5->-r requirements.txt (line 9)) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.29.5->-r requirements.txt (line 9)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.29.5->-r requirements.txt (line 9)) (1.6.0)
# Requirement already satisfied: psutil in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.29.5->-r requirements.txt (line 9)) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.29.5->-r requirements.txt (line 9)) (27.0.0)
# Requirement already satisfied: tornado>=6.1 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.29.5->-r requirements.txt (line 9)) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipykernel>=6.29.5->-r requirements.txt (line 9)) (5.14.3)
# Requirement already satisfied: decorator in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.29.5->-r requirements.txt (line 9)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.29.5->-r requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.29.5->-r requirements.txt (line 9)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.29.5->-r requirements.txt (line 9)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.29.5->-r requirements.txt (line 9)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.29.5->-r requirements.txt (line 9)) (2.19.2)
# Requirement already satisfied: stack_data in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from ipython>=7.23.1->ipykernel>=6.29.5->-r requirements.txt (line 9)) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.29.5->-r requirements.txt (line 9)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.29.5->-r requirements.txt (line 9)) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from jupyter-client>=6.1.12->ipykernel>=6.29.5->-r requirements.txt (line 9)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.29.5->-r requirements.txt (line 9)) (4.3.8)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/homebrew/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /opt/homebrew/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j>=0.2.0->-r requirements.txt (line 1)) (0.23.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.29.5->-r requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=6.29.5->-r requirements.txt (line 9)) (1.17.0)
# Collecting soupsieve>1.2 (from beautifulsoup4->wikipedia>=1.4.0->-r requirements.txt (line 5))
#   Using cached soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: executing>=1.2.0 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.29.5->-r requirements.txt (line 9)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.29.5->-r requirements.txt (line 9)) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/jayanthsattineni/Library/Python/3.11/lib/python/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.29.5->-r requirements.txt (line 9)) (0.2.3)
# Using cached langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Using cached pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading langchain_experimental-0.3.4-py3-none-any.whl (209 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Using cached soupsieve-2.7-py3-none-any.whl (36 kB)
# Building wheels for collected packages: wikipedia
#   DEPRECATION: Building 'wikipedia' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'wikipedia'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11757 sha256=0c7c8ce2e0506af7c6d1813e6aaa34c2b1ec54039f453093fd1b9c1c7d88e98d
#   Stored in directory: /Users/jayanthsattineni/Library/Caches/pip/wheels/8f/ab/cb/45ccc40522d3a1c41e1d2ad53b8f33a62f394011ec38cd71c6
# Successfully built wikipedia
# Installing collected packages: soupsieve, mypy-extensions, marshmallow, httpx-sse, typing-inspect, beautifulsoup4, wikipedia, pydantic-settings, dataclasses-json, langchain-community, langchain-experimental
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [langchain-experimental]hain-experimental]
# Successfully installed beautifulsoup4-4.13.4 dataclasses-json-0.6.7 httpx-sse-0.4.1 langchain-community-0.3.27 langchain-experimental-0.3.4 marshmallow-3.26.1 mypy-extensions-1.1.0 pydantic-settings-2.10.1 soupsieve-2.7 typing-inspect-0.9.0 wikipedia-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install neo4j
# Out:
# Requirement already satisfied: neo4j in /opt/homebrew/lib/python3.11/site-packages (5.28.1)
# Requirement already satisfied: pytz in /opt/homebrew/lib/python3.11/site-packages (from neo4j) (2025.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from neo4j import GraphDatabase
from langchain_groq import ChatGroq
from langchain_neo4j  import Neo4jGraph
from dotenv import load_dotenv

load_dotenv(override=True)

from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_community.document_loaders import WikipediaLoader
from langchain.text_splitter import TokenTextSplitter

from langchain_community.vectorstores.neo4j_vector import remove_lucene_chars
from langchain_core.prompts import ChatPromptTemplate

# %%
kg = Neo4jGraph(
    url="neo4j://127.0.0.1:7687", username="neo4j", password="user@123", enhanced_schema=True, 
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 kg = Neo4jGraph(
#       2     url="neo4j://127.0.0.1:7687", username="neo4j", password="user@123", enhanced_schema=True, database_config={"notifications_min_severity": "ERROR"}
#       3 )
#
# TypeError: Neo4jGraph.__init__() got an unexpected keyword argument 'database_config'

# %% [markdown]
# # Wipe Out The DB

# %%
kg.query("MATCH(n) DETACH DELETE n")
# Out:
# []

# %% [markdown]
# # Initialize LLM

# %%
llm = ChatGroq(temperature=0, groq_api_key=os.environ['GROQ_KEY'], model_name="llama-3.3-70b-versatile")

# %%
raw_documents = WikipediaLoader(query="Ramayana").load()
text_splitter = TokenTextSplitter(chunk_size=512, chunk_overlap=24)
documents = text_splitter.split_documents(raw_documents[:3])
# Out:
# /opt/homebrew/lib/python3.11/site-packages/wikipedia/wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /opt/homebrew/lib/python3.11/site-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')

# %% [markdown]
# # Generate Knowledge Graph

# %%
transformer = LLMGraphTransformer(llm=llm)
graph_documents = transformer.convert_to_graph_documents(documents)

# %% [markdown]
# # Ingest Data To KG

# %%
kg.add_graph_documents(
  graph_documents, 
  baseEntityLabel=True, 
  include_source=True
)

# %% [markdown]
# # Create FULL TEXT INDEX

# %%
kg.query(
    "CREATE FULLTEXT INDEX entity IF NOT EXISTS FOR (e:__Entity__) ON EACH [e.id]")
# Out:
# []

# %% [markdown]
# # Schema Visualization

# %%
print(kg.schema)
# Out:
# Node properties:
# - **Document**
#   - `id`: STRING Available options: ['95376fe4974ad6af7ed541292732f6e6', '943f711142ed09016566c94df41c4289', '077c764928f6df391f2bc56c8fb1fb60', '16bf162388d87cdbbf595b5e856b3857', 'c19c9b670ba929dd23fa7f760fc29b77', '98926dcad461da97ee60f6dfa7a3dbfa', '692722004c6121da2b2db5da2984e8fe', 'c9ced462c75058643845b3a325db5f33']
#   - `text`: STRING Available options: [' Buddhist. Its most important moral influence was ', ' narrative contradictions between these two volume', 'Ramayana: The Legend of Prince Rama is a 1993 anim', ' Bulbul Mukherjee – Dasharatha Madhulika Varma – K', ' B. B. Lal near Allahabad in Uttar Pradesh (India)', 'Rama (; Sanskrit: राम, IAST: Rāma, Sanskrit: [ˈraː', ' significantly from the Hindu versions. Jain Texts', 'The Ramayana (; Sanskrit: रामायणम्, romanized: Rām']
#   - `summary`: STRING Available options: ['The Ramayana (; Sanskrit: रामायणम्, romanized: Rām', 'Ramayana: The Legend of Prince Rama is a 1993 anim', 'Rama (; Sanskrit: राम, IAST: Rāma, Sanskrit: [ˈraː']
#   - `source`: STRING Available options: ['https://en.wikipedia.org/wiki/Ramayana', 'https://en.wikipedia.org/wiki/Ramayana:_The_Legend', 'https://en.wikipedia.org/wiki/Rama']
#   - `title`: STRING Available options: ['Ramayana', 'Ramayana: The Legend of Prince Rama', 'Rama']
# - **Epic**
#   - `id`: STRING Available options: ['Ramayana']
# - **Author**
#   - `id`: STRING Available options: ['Valmiki']
# - **Prince**
#   - `id`: STRING Available options: ['Rama', 'Lakshmana']
# - **Deity**
#   - `id`: STRING Available options: ['Rama', 'Vishnu']
# - **Kingdom**
#   - `id`: STRING Available options: ['Ayodhya', 'Kosala', 'Lanka', 'Magadha']
# - **King**
#   - `id`: STRING Available options: ['King Dasharatha', 'Ravana']
# - **Queen**
#   - `id`: STRING Available options: ['Kaikeyi', 'Sita']
# - **State**
#   - `id`: STRING Available options: ['Rāmarājya']
# - **Person**
#   - `id`: STRING Example: "Rama"
# - **Religion**
#   - `id`: STRING Available options: ['Buddhism', 'Hinduism', 'Jainism', 'Sikhism']
# - **Text**
#   - `id`: STRING Available options: ['Atharvaveda', 'Mahabharata', 'Atharva Veda', 'Rigveda']
# - **City**
#   - `id`: STRING Available options: ['Ayodhya', 'Saketa', 'Shravasti']
# - **Scholar**
#   - `id`: STRING Available options: ['Hermann Jacobi']
# - **Film**
#   - `id`: STRING Available options: ['Ramayana: The Legend Of Prince Rama']
# - **Country**
#   - `id`: STRING Available options: ['India', 'Japan']
# - **Festival**
#   - `id`: STRING Available options: ['24Th International Film Festival Of India', '1993 Vancouver International Film Festival', 'Rama Navami']
# - **Location**
#   - `id`: STRING Available options: ['Ayodhya', 'Lanka', 'India', 'Panchavati', 'Kishkindha', 'Allahabad', 'Uttar Pradesh']
# - **Actor**
#   - `id`: STRING Example: "Bulbul Mukherjee"
# - **Character**
#   - `id`: STRING Example: "Rama"
# - **Documentary film**
#   - `id`: STRING Available options: ['The Ramayana Relics']
# - **Story**
#   - `id`: STRING Available options: ['Ramayana']
# - **Documentary**
#   - `id`: STRING Available options: ['The Ramayana Relics']
# - **Newspaper**
#   - `id`: STRING Available options: ['The Indian Express']
# - **Organization**
#   - `id`: STRING Available options: ['Vishva Hindu Parishad', 'Japanese Embassy']
# - **Demon-king**
#   - `id`: STRING Available options: ['Ravana']
# - **Sect**
#   - `id`: STRING Available options: ['Vaishnavism']
# Relationship properties:
#
# The relationships:
# (:Document)-[:MENTIONS]->(:Prince)
# (:Document)-[:MENTIONS]->(:Deity)
# (:Document)-[:MENTIONS]->(:Person)
# (:Document)-[:MENTIONS]->(:Character)
# (:Document)-[:MENTIONS]->(:Kingdom)
# (:Document)-[:MENTIONS]->(:City)
# (:Document)-[:MENTIONS]->(:Location)
# (:Document)-[:MENTIONS]->(:State)
# (:Document)-[:MENTIONS]->(:Religion)
# (:Document)-[:MENTIONS]->(:Text)
# (:Document)-[:MENTIONS]->(:Scholar)
# (:Document)-[:MENTIONS]->(:Epic)
# (:Document)-[:MENTIONS]->(:Story)
# (:Document)-[:MENTIONS]->(:Queen)
# (:Document)-[:MENTIONS]->(:King)
# (:Document)-[:MENTIONS]->(:Demon-king)
# (:Document)-[:MENTIONS]->(:Film)
# (:Document)-[:MENTIONS]->(:Country)
# (:Document)-[:MENTIONS]->(:Festival)
# (:Document)-[:MENTIONS]->(:Actor)
# (:Document)-[:MENTIONS]->(:Documentary film)
# (:Document)-[:MENTIONS]->(:Documentary)
# (:Document)-[:MENTIONS]->(:Newspaper)
# (:Document)-[:MENTIONS]->(:Organization)
# (:Document)-[:MENTIONS]->(:Sect)
# (:Document)-[:MENTIONS]->(:Author)
# (:Author)-[:AUTHOR]->(:Epic)
# (:Author)-[:AUTHOR]->(:Story)
# (:Prince)-[:AVATAR]->(:Deity)
# (:Prince)-[:PRINCE]->(:Kingdom)
# (:Prince)-[:PRINCE]->(:City)
# (:Prince)-[:PRINCE]->(:Location)
# (:Prince)-[:HUSBAND]->(:Queen)
# (:Prince)-[:HUSBAND]->(:Person)
# (:Prince)-[:HUSBAND]->(:Character)
# (:Prince)-[:BROTHER]->(:Prince)
# (:Prince)-[:BROTHER]->(:Person)
# (:Prince)-[:BROTHER]->(:Character)
# (:Prince)-[:KING]->(:State)
# (:Prince)-[:PART_OF]->(:Kingdom)
# (:Prince)-[:PART_OF]->(:Religion)
# (:Prince)-[:MENTIONED_IN]->(:Religion)
# (:Prince)-[:MENTIONED_IN]->(:Text)
# (:Prince)-[:EXILED_TO]->(:Location)
# (:Prince)-[:ASSOCIATED_WITH]->(:Religion)
# (:Prince)-[:AVATAR_OF]->(:Deity)
# (:Prince)-[:HONORED_IN]->(:Festival)
# (:Prince)-[:SON_OF]->(:Person)
# (:Prince)-[:SON_OF]->(:Character)
# (:Prince)-[:BORN_IN]->(:Kingdom)
# (:Prince)-[:BORN_IN]->(:City)
# (:Prince)-[:BORN_IN]->(:Location)
# (:Prince)-[:BROTHER_OF]->(:Prince)
# (:Prince)-[:BROTHER_OF]->(:Person)
# (:Prince)-[:BROTHER_OF]->(:Character)
# (:Prince)-[:BROTHER_OF]->(:Deity)
# (:Prince)-[:HUSBAND_OF]->(:Queen)
# (:Prince)-[:HUSBAND_OF]->(:Person)
# (:Prince)-[:HUSBAND_OF]->(:Character)
# (:Prince)-[:ENEMY_OF]->(:King)
# (:Prince)-[:ENEMY_OF]->(:Person)
# (:Prince)-[:ENEMY_OF]->(:Character)
# (:Prince)-[:ENEMY_OF]->(:Demon-king)
# (:Prince)-[:IMPORTANT_TO]->(:Sect)
# (:Prince)-[:MAIN_CHARACTER_OF]->(:Epic)
# (:Prince)-[:MAIN_CHARACTER_OF]->(:Story)
# (:Prince)-[:KING_OF]->(:Kingdom)
# (:Prince)-[:KING_OF]->(:City)
# (:Prince)-[:KING_OF]->(:Location)
# (:Deity)-[:AVATAR]->(:Deity)
# (:Deity)-[:PRINCE]->(:Kingdom)
# (:Deity)-[:PRINCE]->(:City)
# (:Deity)-[:PRINCE]->(:Location)
# (:Deity)-[:HUSBAND]->(:Queen)
# (:Deity)-[:HUSBAND]->(:Person)
# (:Deity)-[:HUSBAND]->(:Character)
# (:Deity)-[:BROTHER]->(:Prince)
# (:Deity)-[:BROTHER]->(:Person)
# (:Deity)-[:BROTHER]->(:Character)
# (:Deity)-[:KING]->(:State)
# (:Deity)-[:PART_OF]->(:Kingdom)
# (:Deity)-[:PART_OF]->(:Religion)
# (:Deity)-[:MENTIONED_IN]->(:Religion)
# (:Deity)-[:MENTIONED_IN]->(:Text)
# (:Deity)-[:EXILED_TO]->(:Location)
# (:Deity)-[:ASSOCIATED_WITH]->(:Religion)
# (:Deity)-[:AVATAR_OF]->(:Deity)
# (:Deity)-[:AVATAR_OF]->(:Person)
# (:Deity)-[:HONORED_IN]->(:Festival)
# (:Deity)-[:SON_OF]->(:Person)
# (:Deity)-[:SON_OF]->(:Character)
# (:Deity)-[:BORN_IN]->(:Kingdom)
# (:Deity)-[:BORN_IN]->(:City)
# (:Deity)-[:BORN_IN]->(:Location)
# (:Deity)-[:BROTHER_OF]->(:Prince)
# (:Deity)-[:BROTHER_OF]->(:Person)
# (:Deity)-[:BROTHER_OF]->(:Character)
# (:Deity)-[:HUSBAND_OF]->(:Queen)
# (:Deity)-[:HUSBAND_OF]->(:Person)
# (:Deity)-[:HUSBAND_OF]->(:Character)
# (:Deity)-[:ENEMY_OF]->(:King)
# (:Deity)-[:ENEMY_OF]->(:Person)
# (:Deity)-[:ENEMY_OF]->(:Character)
# (:Deity)-[:ENEMY_OF]->(:Demon-king)
# (:Deity)-[:IMPORTANT_TO]->(:Sect)
# (:Deity)-[:MAIN_CHARACTER_OF]->(:Epic)
# (:Deity)-[:MAIN_CHARACTER_OF]->(:Story)
# (:Deity)-[:KING_OF]->(:Kingdom)
# (:Deity)-[:KING_OF]->(:City)
# (:Deity)-[:KING_OF]->(:Location)
# (:Kingdom)-[:PART_OF]->(:Kingdom)
# (:Kingdom)-[:COEXISTED_WITH]->(:Kingdom)
# (:King)-[:FATHER]->(:Prince)
# (:King)-[:FATHER]->(:Deity)
# (:King)-[:FATHER]->(:Person)
# (:King)-[:FATHER]->(:Character)
# (:King)-[:ABDUCTOR_OF]->(:Queen)
# (:King)-[:ABDUCTOR_OF]->(:Person)
# (:King)-[:ABDUCTOR_OF]->(:Character)
# (:King)-[:KING_OF]->(:Kingdom)
# (:King)-[:KING_OF]->(:Location)
# (:King)-[:KIDNAPPER]->(:Queen)
# (:King)-[:KIDNAPPER]->(:Person)
# (:King)-[:KIDNAPPER]->(:Character)
# (:Queen)-[:WIFE_OF]->(:Person)
# (:Queen)-[:WIFE_OF]->(:Character)
# (:Queen)-[:WIFE_OF]->(:Prince)
# (:Queen)-[:WIFE_OF]->(:Deity)
# (:Queen)-[:STEPMOTHER]->(:Prince)
# (:Queen)-[:STEPMOTHER]->(:Deity)
# (:Queen)-[:STEPMOTHER]->(:Person)
# (:Queen)-[:STEPMOTHER]->(:Character)
# (:State)-[:CAPITAL]->(:Kingdom)
# (:State)-[:CAPITAL]->(:City)
# (:State)-[:CAPITAL]->(:Location)
# (:Person)-[:AVATAR]->(:Deity)
# (:Person)-[:PRINCE]->(:Kingdom)
# (:Person)-[:PRINCE]->(:City)
# (:Person)-[:PRINCE]->(:Location)
# (:Person)-[:HUSBAND]->(:Queen)
# (:Person)-[:HUSBAND]->(:Person)
# (:Person)-[:HUSBAND]->(:Character)
# (:Person)-[:BROTHER]->(:Prince)
# (:Person)-[:BROTHER]->(:Person)
# (:Person)-[:BROTHER]->(:Character)
# (:Person)-[:KING]->(:State)
# (:Person)-[:PART_OF]->(:Kingdom)
# (:Person)-[:PART_OF]->(:Religion)
# (:Person)-[:MENTIONED_IN]->(:Religion)
# (:Person)-[:MENTIONED_IN]->(:Text)
# (:Person)-[:EXILED_TO]->(:Location)
# (:Person)-[:ASSOCIATED_WITH]->(:Religion)
# (:Person)-[:ASSOCIATED_WITH]->(:Documentary film)
# (:Person)-[:ASSOCIATED_WITH]->(:Documentary)
# (:Person)-[:AVATAR_OF]->(:Deity)
# (:Person)-[:HONORED_IN]->(:Festival)
# (:Person)-[:SON_OF]->(:Person)
# (:Person)-[:SON_OF]->(:Character)
# (:Person)-[:BORN_IN]->(:Kingdom)
# (:Person)-[:BORN_IN]->(:City)
# (:Person)-[:BORN_IN]->(:Location)
# (:Person)-[:BROTHER_OF]->(:Prince)
# (:Person)-[:BROTHER_OF]->(:Person)
# (:Person)-[:BROTHER_OF]->(:Character)
# (:Person)-[:BROTHER_OF]->(:Deity)
# (:Person)-[:HUSBAND_OF]->(:Queen)
# (:Person)-[:HUSBAND_OF]->(:Person)
# (:Person)-[:HUSBAND_OF]->(:Character)
# (:Person)-[:ENEMY_OF]->(:King)
# (:Person)-[:ENEMY_OF]->(:Person)
# (:Person)-[:ENEMY_OF]->(:Character)
# (:Person)-[:ENEMY_OF]->(:Demon-king)
# (:Person)-[:IMPORTANT_TO]->(:Sect)
# (:Person)-[:MAIN_CHARACTER_OF]->(:Epic)
# (:Person)-[:MAIN_CHARACTER_OF]->(:Story)
# (:Person)-[:KING_OF]->(:Kingdom)
# (:Person)-[:KING_OF]->(:City)
# (:Person)-[:KING_OF]->(:Location)
# (:Person)-[:WIFE_OF]->(:Person)
# (:Person)-[:WIFE_OF]->(:Character)
# (:Person)-[:WIFE_OF]->(:Prince)
# (:Person)-[:WIFE_OF]->(:Deity)
# (:Person)-[:STEPMOTHER]->(:Prince)
# (:Person)-[:STEPMOTHER]->(:Deity)
# (:Person)-[:STEPMOTHER]->(:Person)
# (:Person)-[:STEPMOTHER]->(:Character)
# (:Person)-[:ABDUCTOR_OF]->(:Queen)
# (:Person)-[:ABDUCTOR_OF]->(:Person)
# (:Person)-[:ABDUCTOR_OF]->(:Character)
# (:Person)-[:KIDNAPPER]->(:Queen)
# (:Person)-[:KIDNAPPER]->(:Person)
# (:Person)-[:KIDNAPPER]->(:Character)
# (:Person)-[:PRODUCER]->(:Film)
# (:Person)-[:WORKED_ON]->(:Documentary film)
# (:Person)-[:WORKED_ON]->(:Documentary)
# (:Person)-[:RESEARCHED]->(:Epic)
# (:Person)-[:RESEARCHED]->(:Story)
# (:Person)-[:CREATED]->(:Documentary film)
# (:Person)-[:CREATED]->(:Documentary)
# (:Person)-[:DIRECTOR]->(:Film)
# (:Person)-[:COMPOSER]->(:Film)
# (:Person)-[:RESIDENT_OF]->(:Location)
# (:Person)-[:HELPER_OF]->(:Prince)
# (:Person)-[:HELPER_OF]->(:Deity)
# (:Person)-[:HELPER_OF]->(:Person)
# (:Person)-[:HELPER_OF]->(:Character)
# (:Person)-[:VOICE_ACTOR_OF]->(:Prince)
# (:Person)-[:VOICE_ACTOR_OF]->(:Deity)
# (:Person)-[:VOICE_ACTOR_OF]->(:Person)
# (:Person)-[:VOICE_ACTOR_OF]->(:Character)
# (:Person)-[:VOICE_ACTOR_OF]->(:Queen)
# (:Person)-[:VOICE_ACTOR_OF]->(:King)
# (:Person)-[:VOICE_ACTOR_OF]->(:Demon-king)
# (:Person)-[:VOICE_ACTOR_OF]->(:Film)
# (:Person)-[:PORTRAYED]->(:Person)
# (:Person)-[:PORTRAYED]->(:Character)
# (:Person)-[:PORTRAYED]->(:Queen)
# (:City)-[:PART_OF]->(:Kingdom)
# (:Scholar)-[:SCHOLAR]->(:Epic)
# (:Scholar)-[:SCHOLAR]->(:Story)
# (:Film)-[:SCREENED_AT]->(:Festival)
# (:Country)-[:CO-PRODUCER]->(:Film)
# (:Location)-[:PART_OF]->(:Kingdom)
# (:Location)-[:CO-PRODUCER]->(:Film)
# (:Actor)-[:VOICE_ACTOR_OF]->(:Person)
# (:Actor)-[:VOICE_ACTOR_OF]->(:Character)
# (:Actor)-[:VOICE_ACTOR_OF]->(:Queen)
# (:Actor)-[:PORTRAYED]->(:Person)
# (:Actor)-[:PORTRAYED]->(:Character)
# (:Actor)-[:PORTRAYED]->(:Queen)
# (:Actor)-[:PORTRAYED]->(:Prince)
# (:Actor)-[:PORTRAYED]->(:Deity)
# (:Actor)-[:PORTRAYED]->(:King)
# (:Actor)-[:PORTRAYED]->(:Demon-king)
# (:Character)-[:AVATAR]->(:Deity)
# (:Character)-[:PRINCE]->(:Kingdom)
# (:Character)-[:PRINCE]->(:City)
# (:Character)-[:PRINCE]->(:Location)
# (:Character)-[:HUSBAND]->(:Queen)
# (:Character)-[:HUSBAND]->(:Person)
# (:Character)-[:HUSBAND]->(:Character)
# (:Character)-[:BROTHER]->(:Prince)
# (:Character)-[:BROTHER]->(:Person)
# (:Character)-[:BROTHER]->(:Character)
# (:Character)-[:KING]->(:State)
# (:Character)-[:PART_OF]->(:Kingdom)
# (:Character)-[:PART_OF]->(:Religion)
# (:Character)-[:MENTIONED_IN]->(:Religion)
# (:Character)-[:MENTIONED_IN]->(:Text)
# (:Character)-[:EXILED_TO]->(:Location)
# (:Character)-[:ASSOCIATED_WITH]->(:Religion)
# (:Character)-[:AVATAR_OF]->(:Deity)
# (:Character)-[:HONORED_IN]->(:Festival)
# (:Character)-[:SON_OF]->(:Person)
# (:Character)-[:SON_OF]->(:Character)
# (:Character)-[:BORN_IN]->(:Kingdom)
# (:Character)-[:BORN_IN]->(:City)
# (:Character)-[:BORN_IN]->(:Location)
# (:Character)-[:BROTHER_OF]->(:Prince)
# (:Character)-[:BROTHER_OF]->(:Person)
# (:Character)-[:BROTHER_OF]->(:Character)
# (:Character)-[:BROTHER_OF]->(:Deity)
# (:Character)-[:HUSBAND_OF]->(:Queen)
# (:Character)-[:HUSBAND_OF]->(:Person)
# (:Character)-[:HUSBAND_OF]->(:Character)
# (:Character)-[:ENEMY_OF]->(:King)
# (:Character)-[:ENEMY_OF]->(:Person)
# (:Character)-[:ENEMY_OF]->(:Character)
# (:Character)-[:ENEMY_OF]->(:Demon-king)
# (:Character)-[:IMPORTANT_TO]->(:Sect)
# (:Character)-[:MAIN_CHARACTER_OF]->(:Epic)
# (:Character)-[:MAIN_CHARACTER_OF]->(:Story)
# (:Character)-[:KING_OF]->(:Kingdom)
# (:Character)-[:KING_OF]->(:City)
# (:Character)-[:KING_OF]->(:Location)
# (:Character)-[:WIFE_OF]->(:Person)
# (:Character)-[:WIFE_OF]->(:Character)
# (:Character)-[:WIFE_OF]->(:Prince)
# (:Character)-[:WIFE_OF]->(:Deity)
# (:Character)-[:STEPMOTHER]->(:Prince)
# (:Character)-[:STEPMOTHER]->(:Deity)
# (:Character)-[:STEPMOTHER]->(:Person)
# (:Character)-[:STEPMOTHER]->(:Character)
# (:Character)-[:ABDUCTOR_OF]->(:Queen)
# (:Character)-[:ABDUCTOR_OF]->(:Person)
# (:Character)-[:ABDUCTOR_OF]->(:Character)
# (:Character)-[:KIDNAPPER]->(:Queen)
# (:Character)-[:KIDNAPPER]->(:Person)
# (:Character)-[:KIDNAPPER]->(:Character)
# (:Character)-[:RESIDENT_OF]->(:Location)
# (:Newspaper)-[:PUBLISHED]->(:Documentary film)
# (:Newspaper)-[:PUBLISHED]->(:Documentary)
# (:Organization)-[:PROTESTED]->(:Organization)
# (:Demon-king)-[:ABDUCTOR_OF]->(:Queen)
# (:Demon-king)-[:ABDUCTOR_OF]->(:Person)
# (:Demon-king)-[:ABDUCTOR_OF]->(:Character)
# (:Demon-king)-[:KING_OF]->(:Kingdom)
# (:Demon-king)-[:KING_OF]->(:Location)
# (:Demon-king)-[:KIDNAPPER]->(:Queen)
# (:Demon-king)-[:KIDNAPPER]->(:Person)
# (:Demon-king)-[:KIDNAPPER]->(:Character)

# %%
from pydantic import BaseModel, Field
from typing import List

class Entities(BaseModel):
    """Identifying information about entities."""

    names: List[str] = Field(
        ...,
        description="All the person, organization, or business entities that "
        "appear in the text",
    )

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are extracting organization and person entities from the text.",
        ),
        (
            "human",
            "Use the given format to extract information from the following "
            "input: {question}",
        ),
    ]
)

entity_chain = prompt | llm.with_structured_output(Entities)

# %%
def generate_full_text_query(input: str) -> str:
    """
    Generate a full-text search query for a given input string.

    This function constructs a query string suitable for a full-text search.
    It processes the input string by splitting it into words and appending a
    similarity threshold (~2 changed characters) to each word, then combines 
    them using the AND operator. Useful for mapping entities from user questions
    to database values, and allows for some misspelings.
    """
    full_text_query = ""
    words = [el for el in remove_lucene_chars(input).split() if el]
    for word in words[:-1]:
        full_text_query += f" {word}~2 AND"
    full_text_query += f" {words[-1]}~2"
    return full_text_query.strip()

# %%
def structured_retriever(question: str) -> str:
    """
    Collects the neighborhood of entities mentioned
    in the question
    """
    result = ""
    entities = entity_chain.invoke({"question": question})
    for entity in entities.names:
        response = kg.query(
            """CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})
            YIELD node,score
            CALL {
              MATCH (node)-[r:!MENTIONS]->(neighbor)
              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output
              UNION
              MATCH (node)<-[r:!MENTIONS]-(neighbor)
              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output
            }
            RETURN output
            """,
            {"query": generate_full_text_query(entity)},
        )
        result += "\n".join([el['output'] for el in response])
    return result

# %%
def retriever(question: str):
    print(f"Search query: {question}")
    structured_data = structured_retriever(question)
    final_data = f"""Structured data:
{structured_data}
    """
    return final_data

# %%
def answer_question(question: str):
    context = retriever(question)
    template = """Answer the question based only on the following context:
{context}
Question: {question}"""
    prompt = ChatPromptTemplate.from_messages([
        ("system", "You are to convert structured data into a clean, human-readable answer. Also print the relevent structure data you are refering from the context."),
        ("human", template),
    ])
    messages = prompt.format_messages(context=context, question=question)
    response = llm(messages)
    return response.content

# %%
print(answer_question("how is Kritarth Trivedi related to Rama"))
print(answer_question("who is the author of ramayana"))
# Out:
# Search query: how is Kritarth Trivedi related to Rama
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL () { ... }} {position: line: 3, column: 13, offset: 104} for query: "CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})\n            YIELD node,score\n            CALL {\n              MATCH (node)-[r:!MENTIONS]->(neighbor)\n              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output\n              UNION\n              MATCH (node)<-[r:!MENTIONS]-(neighbor)\n              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output\n            }\n            RETURN output\n            "
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL () { ... }} {position: line: 3, column: 13, offset: 104} for query: "CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})\n            YIELD node,score\n            CALL {\n              MATCH (node)-[r:!MENTIONS]->(neighbor)\n              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output\n              UNION\n              MATCH (node)<-[r:!MENTIONS]-(neighbor)\n              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output\n            }\n            RETURN output\n            "
# There is no information in the provided structured data about Kritarth Trivedi or their relation to Rama.
#
# Relevant structured data: None
# Search query: who is the author of ramayana
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL () { ... }} {position: line: 3, column: 13, offset: 104} for query: "CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})\n            YIELD node,score\n            CALL {\n              MATCH (node)-[r:!MENTIONS]->(neighbor)\n              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output\n              UNION\n              MATCH (node)<-[r:!MENTIONS]-(neighbor)\n              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output\n            }\n            RETURN output\n            "
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.FeatureDeprecationWarning} {category: DEPRECATION} {title: This feature is deprecated and will be removed in future versions.} {description: CALL subquery without a variable scope clause is now deprecated. Use CALL () { ... }} {position: line: 3, column: 13, offset: 104} for query: "CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})\n            YIELD node,score\n            CALL {\n              MATCH (node)-[r:!MENTIONS]->(neighbor)\n              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output\n              UNION\n              MATCH (node)<-[r:!MENTIONS]-(neighbor)\n              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output\n            }\n            RETURN output\n            "
# The author of the Ramayana is Valmiki.
#
# Relevant structured data:
# Valmiki - AUTHOR -> Ramayana
